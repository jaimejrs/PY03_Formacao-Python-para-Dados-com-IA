# %%
import psycopg2
from dotenv import load_dotenv
import os

load_dotenv()

conn = psycopg2.connect(
    host=os.getenv('POSTGRES_HOST'),
    database=os.getenv('POSTGRES_DATABASE'),
    user=os.getenv('POSTGRES_USER'),
    password=os.getenv('POSTGRES_PASSWORD'),
    port=os.getenv('POSTGRES_PORT')
)

cursor = conn.cursor()
print('Conexão estabelecida com sucesso!')
# Out:
# Conexão estabelecida com sucesso!

# %%
# %pip install -r requirements.txt

# %%
import mysql.connector

conn_mysql = mysql.connector.connect(
    host=os.getenv('MYSQL_HOST'),
    database=os.getenv('MYSQL_DATABASE'),
    user=os.getenv('MYSQL_USER'),
    password=os.getenv('MYSQL_PASSWORD')
)

cursor_mysql = conn_mysql.cursor()
print('Conexão MySQL estabelecida com sucesso!')
# Out:
# Conexão MySQL estabelecida com sucesso!

# %%
import pandas as pd

query = """
SELECT 'Empresa 01' as empresa, nome_vendedor, sum(valor_venda) as total_vendas        
FROM datadt_curso_python.vendas
GROUP BY nome_vendedor
"""

df = pd.read_sql(query, conn_mysql)
df
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_12524\3873192840.py:9: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, conn_mysql)
#       empresa      nome_vendedor  total_vendas
# 0  Empresa 01       Aline Sutter       6051.99
# 1  Empresa 01       Ana Teixeira      29221.12
# 2  Empresa 01      André Pereira      87964.89
# 3  Empresa 01      Artur Moreira      49944.79
# 4  Empresa 01  Fernando Zambrini      21225.64
# 5  Empresa 01       Josias Silva      50544.17
# 6  Empresa 01    Maria Fernandes      55997.66
# 7  Empresa 01   Mateus Gonçalves      36353.69
# 8  Empresa 01   Rodrigo Fagundes      23777.16

# %%
query_pg = """
SELECT 'Empresa 02' as empresa, pf.nome as nome_vendedor, sum(valor) as total_vendas
FROM vendas.nota_fiscal nf
JOIN geral.pessoa_fisica pf ON pf.id = nf.id_vendedor
GROUP BY pf.nome
"""

df_pg = pd.read_sql(query_pg, conn)
df_pg
# Out:
# C:\Users\danie\AppData\Local\Temp\ipykernel_12524\1682619871.py:8: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_pg = pd.read_sql(query_pg, conn)
#        empresa                    nome_vendedor  total_vendas
# 0   Empresa 02           MARIA DO SOCORRO ALVES     4129952.0
# 1   Empresa 02          ANA PAULA DA SILVA LIMA     3916281.0
# 2   Empresa 02       ANANDA ROSA BESERRA SANTOS     3273739.0
# 3   Empresa 02     WELLINGTON DA SILVA DE SOUSA     3786323.0
# 4   Empresa 02            FLAVIA DA SILVA COSTA     3646854.0
# 5   Empresa 02              JOSE LOPES DA SILVA     3633685.0
# 6   Empresa 02             ALICE ALVES TIBURCIO     3818268.0
# 7   Empresa 02         MARIA APARECIDA DE SOUSA     3603034.0
# 8   Empresa 02       MARIA DE FATIMA DOS SANTOS     3787006.0
# 9   Empresa 02          ANDERSON GOMES DA SILVA     3632866.0
# 10  Empresa 02          BARBARA BATISTA PEREIRA     3461915.0
# 11  Empresa 02         MARIA DE FATIMA DA SILVA     3678364.0
# 12  Empresa 02   FRANCISCO BRUNO ALVES DA SILVA     3620265.0
