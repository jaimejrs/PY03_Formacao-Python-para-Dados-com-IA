# %%
idade = int(input(f'tua idade desgraça:'))

# %%
if idade >= 18:
    print('tu é de maior')
elif idade >= 13:
    print('tu é gaiatin')
else:
    print('tu é kid')
# Out:
# tu é de maior

# %%
renda = float(input('Qual a sua renda?: '))


x = 0.15
y = 0.275

# %%
renda = float(input('Qual a sua renda?: '))

x = 0.15
y = 0.275

# %%
if renda <= 22000:
    print('se safou miserávi')

elif renda >= 22001 and renda <= 50000:
    print(f'se fosse um pouquim mais liso escapava, tu vai pagar {renda * x:.2f}')
else:
    print(f'extribado né? pois tu vai pagar {renda * y:.2f}')
# Out:
# extribado né? pois tu vai pagar 82500.00
